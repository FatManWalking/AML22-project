# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# %%
# %load_ext rpy2.ipython

# %%
# %R library(lme4)
# Out:
# R[write to console]: Loading required package: Matrix
# <rpy2.robjects.vectors.StrVector object at 0x7f5921c60080> [RTYPES.STRSXP]
# R classes: ('character',)
# ['lme4', 'Matrix', 'tools', 'stats', ..., 'utils', 'datasets', 'methods', 'base']

# %%
# Load the data from ../analysis/ENZYMES/graphs_{i}.npy
# where i is the index of the graph
def load_data(i):
    return np.load('../analysis/emp-nci/NCI1/graphs_{}.npy'.format(i), allow_pickle=True)

# %%
def get_cna_metrics():

    # list of graph metrics for each dataset
    all_graph_metrics = []
    datasets = [load_data(i) for i in range(5)]
    
    for dataset in datasets:
        graph_metrics = []
        for graph in dataset:

            graph_metrics.append([
                                  graph.number_of_nodes(),
                                  nx.graph_number_of_cliques(graph),
                                  max(dict(graph.degree).values()),
                                  min(dict(graph.degree).values()),
                                  np.mean(list(dict(graph.degree).values())),
                                  #nx.degree_assortativity_coefficient(graph),
                                  nx.density(graph),
                                  np.mean(list(dict(graph.degree).values())),
                                  nx.average_clustering(graph),
                                  graph.graph['graph_id'],
                                  graph.graph['prediction'],
                                  graph.graph['label'],
                                  graph.graph['softmax'],
                                  graph.graph['correct'],
                                  graph.graph['loss'],
                                  "HGP-SL",
                                  "NCI1",
                                  graph.graph['random_seed'],
                                  graph.graph['dropout_ratio'],
                                  graph.graph['pooling_ratio'],
                                  graph.graph['structure_learning'],
                                  graph.graph['sigmod'],
                                  ])
        all_graph_metrics.append(graph_metrics)
    
    return all_graph_metrics

# %%
def rename_columns(df):
    # maps the index of graph_metrics to the metric name (needed to label automatically in visualization)
    index_to_metric = {
                        0: 'Number_of_Vertices',
                        1: 'Number_of_Cliques',
                        2: 'Maximum_Degree',
                        3: 'Minimum_Degree',
                        4: 'Average_Degree',
                        5: 'Density',
                        6: 'Average_Neighbor_Degree',
                        7: 'Average_Clustering_Coefficient',
                        8: 'Graph_ID',
                        9: 'Prediction',
                        10: 'Label',
                        11: 'Confidence',
                        12: 'Correct',
                        13: 'Loss',
                        14: 'Architecture',
                        15: 'Dataset',
                        16: 'Random_Seed',
                        17: 'Dropout_Ratio',
                        18: 'Pooling_Ratio',
                        19: 'Structure_Learning',
                        20: 'Sigmoid',
                       }

    df = df.rename(columns=index_to_metric)
    return df

# %%
# build a dataframe for each dataset
def build_dataframe(all_graph_metrics):
    df_list = []
    for graph_metrics in all_graph_metrics:
        df = pd.DataFrame(graph_metrics)
        df = rename_columns(df)
        df_list.append(df)
    return df_list

# %%
df_list = build_dataframe(get_cna_metrics())

# %%
architecture = "emp-hgpsl"

# %%
# concatenate the dataframes
df = pd.concat(df_list, ignore_index=True)

# %%
df.value_counts('Pooling_Ratio')
# Out:
# Pooling_Ratio
# 0.3    4112
# 0.5    1028
# dtype: int64

# %%
df.head().T
# Out:
#                                         0         1          2          3  \
# Number_of_Vertices                     26        21         49         61
# Number_of_Cliques                      28        21         51         63
# Maximum_Degree                          3         3          4          4
# Minimum_Degree                          1         1          1          1
# Average_Degree                    2.15385         2    2.08163    2.06557
# Density                         0.0861538       0.1  0.0433673  0.0344262
# Average_Neighbor_Degree           2.15385         2    2.08163    2.06557
# Average_Clustering_Coefficient          0         0          0          0
# Graph_ID                                0         1          2          3
# Prediction                              1         1          1          1
# Label                                   1         0          1          0
# Confidence                       0.589666  0.387471   0.893967   0.110852
# Correct                              True     False       True      False
# Loss                             0.528199  0.948114   0.112087    2.19956
# Architecture                       HGP-SL    HGP-SL     HGP-SL     HGP-SL
# Dataset                              NCI1      NCI1       NCI1       NCI1
# Random_Seed                          1337      1337       1337       1337
# Dropout_Ratio                           0         0          0          0
# Pooling_Ratio                         0.3       0.3        0.3        0.3
# Structure_Learning                  False     False      False      False
# Sigmoid                          0.370937  0.279264   0.472008  0.0997902
#
#                                         4
# Number_of_Vertices                     28
# Number_of_Cliques                      31
# Maximum_Degree                          3
# Minimum_Degree                          1
# Average_Degree                    2.21429
# Density                         0.0820106
# Average_Neighbor_Degree           2.21429
# Average_Clustering_Coefficient          0
# Graph_ID                                4
# Prediction                              0
# Label                                   0
# Confidence                       0.654803
# Correct                              True
# Loss                             0.423421
# Architecture                       HGP-SL
# Dataset                              NCI1
# Random_Seed                          1337
# Dropout_Ratio                           0
# Pooling_Ratio                         0.3
# Structure_Learning                  False
# Sigmoid                          0.395698

# %%
md = smf.mixedlm("Sigmoid ~ Structure_Learning", df, groups=df["Structure_Learning"], re_formula="~Random_Seed")
free = sm.regression.mixed_linear_model.MixedLMParams.from_components(
    np.ones(2), np.eye(2)
)
mdf = md.fit(free=free, method=["lbfgs"])
print(mdf.summary())
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb Cell 13 in <cell line: 5>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> md = smf.mixedlm("Sigmoid ~ Structure_Learning", df, groups=df["Structure_Learning"], re_formula="~Random_Seed")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> free = sm.regression.mixed_linear_model.MixedLMParams.from_components(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     np.ones(2), np.eye(2)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> )
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> mdf = md.fit(free=free, method=["lbfgs"])
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> print(mdf.summary())
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2191, in MixedLM.fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **fit_kwargs)
#    2189 # Try optimizing one or more times
#    2190 for j in range(len(method)):
# -> 2191     rslt = super(MixedLM, self).fit(start_params=packed,
#    2192                                     skip_hessian=True,
#    2193                                     method=method[j],
#    2194                                     **fit_kwargs)
#    2195     if rslt.mle_retvals['converged']:
#    2196         break
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/base/model.py:563, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     560     del kwargs["use_t"]
#     562 optimizer = Optimizer()
# --> 563 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     564                                                fargs, kwargs,
#     565                                                hessian=hess,
#     566                                                method=method,
#     567                                                disp=disp,
#     568                                                maxiter=maxiter,
#     569                                                callback=callback,
#     570                                                retall=retall,
#     571                                                full_output=full_output)
#     572 # Restore cov_type, cov_kwds and use_t
#     573 optim_settings.update(kwds)
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/base/optimizer.py:241, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     238     fit_funcs.update(extra_fit_funcs)
#     240 func = fit_funcs[method]
# --> 241 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     242                      disp=disp, maxiter=maxiter, callback=callback,
#     243                      retall=retall, full_output=full_output,
#     244                      hess=hessian)
#     246 optim_settings = {'optimizer': method, 'start_params': start_params,
#     247                   'maxiter': maxiter, 'full_output': full_output,
#     248                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     249                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     250 optim_settings.update(kwargs)
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/base/optimizer.py:651, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     648 elif approx_grad:
#     649     func = f
# --> 651 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     652                                  callback=callback, args=fargs,
#     653                                  bounds=bounds, disp=disp,
#     654                                  **extra_kwargs)
#     656 if full_output:
#     657     xopt, fopt, d = retvals
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/scipy/optimize/_lbfgsb_py.py:199, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     187     disp = iprint
#     188 opts = {'disp': disp,
#     189         'iprint': iprint,
#     190         'maxcor': m,
#    (...)
#     196         'callback': callback,
#     197         'maxls': maxls}
# --> 199 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                        **opts)
#     201 d = {'grad': res['jac'],
#     202      'task': res['message'],
#     203      'funcalls': res['nfev'],
#     204      'nit': res['nit'],
#     205      'warnflag': res['status']}
#     206 f = res['fun']
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/scipy/optimize/_lbfgsb_py.py:362, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     356 task_str = task.tobytes()
#     357 if task_str.startswith(b'FG'):
#     358     # The minimization routine wants f and g at the current x.
#     359     # Note that interruptions due to maxfun are postponed
#     360     # until the completion of the current minimization iteration.
#     361     # Overwrite f and g:
# --> 362     f, g = func_and_grad(x)
#     363 elif task_str.startswith(b'NEW_X'):
#     364     # new iteration
#     365     n_iterations += 1
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/base/model.py:531, in LikelihoodModel.fit.<locals>.f(params, *args)
#     530 def f(params, *args):
# --> 531     return -self.loglike(params, *args) / nobs
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1498, in MixedLM.loglike(self, params, profile_fe)
#    1496 # Move to the profile set
#    1497 if profile_fe:
# -> 1498     fe_params, sing = self.get_fe_params(cov_re, vcomp)
#    1499     if sing:
#    1500         self._cov_sing += 1
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1338, in MixedLM.get_fe_params(self, cov_re, vcomp, tol)
#    1336 exog = self.exog_li[group_ix]
#    1337 ex_r, ex2_r = self._aex_r[group_ix], self._aex_r2[group_ix]
# -> 1338 solver = _smw_solver(1., ex_r, ex2_r, cov_re_inv, vc_vari)
#    1339 u = solver(self._endex_li[group_ix])
#    1340 xtxy += np.dot(exog.T, u)
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:501, in _smw_solver(s, A, AtA, Qi, di)
#     499 d = qmat.shape[0]
#     500 qmat.flat[m*(d+1)::d+1] += di
# --> 501 qmati = np.linalg.solve(qmat, A.T)
#     503 def solver(rhs):
#     504     # A is tall and qmati is wide, so we want
#     505     # A * (qmati * rhs) not (A * qmati) * rhs
#     506     ql = np.dot(qmati, rhs)
#
# File <__array_function__ internals>:180, in solve(*args, **kwargs)
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/numpy/linalg/linalg.py:400, in solve(a, b)
#     398 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     399 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 400 r = gufunc(a, b, signature=signature, extobj=extobj)
#     402 return wrap(r.astype(result_t, copy=False))
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
mdf.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                     MixedLM          Dependent Variable:          Loss
# No. Observations:          450              Method:                      REML
# No. Groups:                90               Scale:                       0.1490
# Min. group size:           5                Log-Likelihood:              -454.5579
# Max. group size:           5                Converged:                   No
# Mean group size:           5.0
# ----------------------------------------------------------------------------------
#                                         Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                                1.764    0.075 23.533 0.000  1.617  1.911
# Replication[T.2]                        -0.015    0.068 -0.226 0.822 -0.148  0.118
# Replication[T.3]                         0.011    0.065  0.170 0.865 -0.117  0.139
# Replication[T.4]                         0.165    0.141  1.172 0.241 -0.111  0.440
# Replication[T.5]                         0.033    0.076  0.435 0.664 -0.116  0.182
# Group Var                                0.357
# Group x Replication[T.2] Cov             0.052    0.113
# Replication[T.2] Var                     0.116
# Group x Replication[T.3] Cov            -0.005    0.106
# Replication[T.2] x Replication[T.3] Cov  0.027    0.068
# Replication[T.3] Var                     0.088
# Group x Replication[T.4] Cov             0.494    0.171
# Replication[T.2] x Replication[T.4] Cov  0.085    0.206
# Replication[T.3] x Replication[T.4] Cov  0.122    0.215
# Replication[T.4] Var                     1.481
# Group x Replication[T.5] Cov             0.050    0.131
# Replication[T.2] x Replication[T.5] Cov  0.064    0.104
# Replication[T.3] x Replication[T.5] Cov  0.107    0.118
# Replication[T.4] x Replication[T.5] Cov  0.374    0.119
# Replication[T.5] Var                     0.224
# ==================================================================================
#
# """

# %%
#The authors of pymer4 recommend to add the following lines when pymer is run inside a jupyter notebook.
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
import numpy  as np
import pandas as pd
from pymer4.models import Lmer # just import the linear mixed models class 
import scipy.stats as stats

# %%
eval_data = df.astype({"Graph_ID" : 'category', "Correct" : 'category', "Prediction" : 'category', "Label" : 'category', "Replication" : 'category', "system" : 'category'})

# %%
eval_data
# Out:
#      Number_of_Vertices  Number_of_Cliques  Maximum_Degree  Minimum_Degree  \
# 0                    10                  5               5               2
# 1                    50                 74               5               2
# 2                    34                 39               6               2
# 3                    33                 37               6               3
# 4                    52                 68               6               2
# ..                  ...                ...             ...             ...
# 445                  16                 13               7               3
# 446                  39                 24               6               3
# 447                  28                 21               6               3
# 448                  44                 56               7               1
# 449                  88                128               8               1
#
#      Average_Degree   Density  Average_Neighbor_Degree  \
# 0          4.000000  0.444444                 4.000000
# 1          3.560000  0.072653                 3.560000
# 2          3.705882  0.112299                 3.705882
# 3          4.606061  0.143939                 4.606061
# 4          3.769231  0.073906                 3.769231
# ..              ...       ...                      ...
# 445        4.500000  0.300000                 4.500000
# 446        3.538462  0.093117                 3.538462
# 447        3.857143  0.142857                 3.857143
# 448        4.090909  0.095137                 4.090909
# 449        3.022727  0.034744                 3.022727
#
#      Average_Clustering_Coefficient Graph_ID Prediction Label  Confidence  \
# 0                          0.740000        0          1     1    0.859586
# 1                          0.156667        1          0     3    0.484204
# 2                          0.282353        2          2     0    0.263705
# 3                          0.475758        3          5     0    0.263545
# 4                          0.204487        4          5     4    0.263197
# ..                              ...      ...        ...   ...         ...
# 445                        0.646726       85          2     4    0.560666
# 446                        0.639316       86          5     5    0.194918
# 447                        0.617857       87          5     1    0.340789
# 448                        0.249134       88          2     3    0.281418
# 449                        0.022700       89          2     5    0.295143
#
#     Correct      Loss Replication     system
# 0      True  0.151305           1  emp-hgpsl
# 1     False  3.047505           1  emp-hgpsl
# 2     False  1.706103           1  emp-hgpsl
# 3     False  1.803389           1  emp-hgpsl
# 4     False  2.539231           1  emp-hgpsl
# ..      ...       ...         ...        ...
# 445   False  1.756383           5  emp-hgpsl
# 446    True  1.635175           5  emp-hgpsl
# 447   False  1.528071           5  emp-hgpsl
# 448   False  1.927752           5  emp-hgpsl
# 449   False  3.221134           5  emp-hgpsl
#
# [450 rows x 16 columns]

# %%
differentMeans_model = Lmer(formula = "Loss ~ Replication + (1 | Graph_ID)", data = eval_data)

# %%
differentMeans_model.fit(factors = {"Replication" : ["1", "2", "3", "4", "5"]}, REML = False, summarize = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/bjoern/AML22-project/Error_Analysis/stat_analysis.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> differentMeans_model.fit(factors = {"Replication" : ["1", "2", "3", "4", "5"]}, REML = False, summarize = False)
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/pymer4/models/Lmer.py:533, in Lmer.fit(self, conf_int, n_boot, factors, permute, ordered, verbose, REML, rank, rank_group, rank_exclude_cols, no_warnings, control, old_optimizer, **kwargs)
#     531 df = pd.DataFrame(out_summary)
#     532 dfshape = df.shape[1]
# --> 533 df.index = out_rownames
#     535 # gaussian
#     536 if dfshape == 7:
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/pandas/core/generic.py:5154, in NDFrame.__setattr__(self, name, value)
#    5152 try:
#    5153     object.__getattribute__(self, name)
# -> 5154     return object.__setattr__(self, name, value)
#    5155 except AttributeError:
#    5156     pass
#
# File pandas/_libs/properties.pyx:66, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/pandas/core/generic.py:564, in NDFrame._set_axis(self, axis, labels)
#     562 def _set_axis(self, axis: int, labels: Index) -> None:
#     563     labels = ensure_index(labels)
# --> 564     self._mgr.set_axis(axis, labels)
#     565     self._clear_item_cache()
#
# File ~/miniconda3/envs/pymer4/lib/python3.9/site-packages/pandas/core/internals/managers.py:226, in BlockManager.set_axis(self, axis, new_labels)
#     223 new_len = len(new_labels)
#     225 if new_len != old_len:
# --> 226     raise ValueError(
#     227         f"Length mismatch: Expected axis has {old_len} elements, new "
#     228         f"values have {new_len} elements"
#     229     )
#     231 self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
# load df from csv
df = pd.read_csv('../df.csv', index_col=0)

# %%
df
# Out:
#               0           1           2           3           4
# 0  1.763881e+00   -0.015305    0.011152    0.164718    0.033078
# 1  1.088014e-01    0.100171    0.100171    0.100171    0.100171
# 2  1.933044e+02  360.000002  360.000002  360.000002  360.000002
# 3  1.621193e+01   -0.152790    0.111326    1.644377    0.330220
# 4  6.914763e-38    0.878649    0.911420    0.100971    0.741426
# 5  1.550634e+00   -0.211636   -0.185179   -0.031613   -0.163252
# 6  1.977128e+00    0.181026    0.207482    0.361049    0.229409

# %%
df.index = [[1], "(Intercept)", "Replication", "Replication:1", "Replication:2", "Replication:3", "Replication:4"]

# %%
df
# Out:
#                           0           1           2           3           4
# [1]            1.763881e+00   -0.015305    0.011152    0.164718    0.033078
# (Intercept)    1.088014e-01    0.100171    0.100171    0.100171    0.100171
# Replication    1.933044e+02  360.000002  360.000002  360.000002  360.000002
# Replication:1  1.621193e+01   -0.152790    0.111326    1.644377    0.330220
# Replication:2  6.914763e-38    0.878649    0.911420    0.100971    0.741426
# Replication:3  1.550634e+00   -0.211636   -0.185179   -0.031613   -0.163252
# Replication:4  1.977128e+00    0.181026    0.207482    0.361049    0.229409

# %%
d = {
    "Replication" : [1, 2, 3, 4, 5],
    "Loss" : [0.000000, 1.000000, 2.000000, 3.000000, 4.000000],
    "Graph_ID" : [1, 2, 3, 4, 5],
    "Correct" : [1, 2, 3, 4, 5],
    "Prediction" : [1, 2, 3, 4, 5],
    "Label" : [1, 2, 3, 4, 5],
}
